# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs
from pprint import pprint

# %% [markdown]
# ## Extract Information from GUE.com

# %%
GUE_INSTRUCTORS_URL = "https://www.gue.com/diver-training/gue-instructors"
GUE_INSTRUCTOR_RESUME_URL = "https://www.gue.com/diver-training/gue-instructors/instructor-resume?id="

# %%
# Create Soup
page = requests.get(GUE_INSTRUCTORS_URL).content
soup = bs(page, 'html.parser')

# %%
filter_results = {}

instructor_container = soup.find(name='div', attrs={"id": "Content"})
options = instructor_container.find_all(name='option')
prev_option = None
option_values = []

for option in options:
    option_type = None
    if "--" in option.text:
        # Extract Text 
        option_type = option.text.lstrip("-- ").rstrip(" --").split(" ")[1].lower()
        if not prev_option:
            prev_option = option_type
        if prev_option != option_type:
            filter_results.update({prev_option: option_values})
            option_values = []
            prev_option = option_type
    else:
        option_values.append((option.get("value"), option.text.strip("\xa0\xa0").title()))

# %%
# Remove Regions from Locations
filter_results.update({'location': [x for x in filter_results.get('location') if len(x[0]) <= 2]})
pprint(filter_results)
# Out:
# {'course': [('100', 'Recreational'),
#             ('53', 'Discover Diving'),
#             ('54', 'Recreational Supervised Diver'),
#             ('21', 'Recreational Diver 1 - Nitrox'),
#             ('44', 'Recreational Diver 2 - Triox'),
#             ('35', 'Recreational Diver 3 - Trimix'),
#             ('200', 'Foundational'),
#             ('1', 'Gue Fundamentals'),
#             ('34', 'Doubles Diver'),
#             ('33', 'Drysuit Diver'),
#             ('31', 'Dpv Diver 1'),
#             ('45', 'Dpv Cave'),
#             ('41', 'Documentation Diver'),
#             ('57', 'Photogrammetry Diver'),
#             ('51', 'Scientific Diver'),
#             ('43', 'Gas Blender'),
#             ('9', 'Triox Primer'),
#             ('62', 'Navigation Primer'),
#             ('61', 'Rescue Primer'),
#             ('300', 'Cave'),
#             ('2', 'Cave Diver 1'),
#             ('3', 'Cave Diver 2'),
#             ('46', 'Underwater Cave Survey'),
#             ('59', 'Cave Sidemount'),
#             ('65', 'Ccr Cave'),
#             ('400', 'Technical'),
#             ('5', 'Technical Diver 1'),
#             ('6', 'Technical Diver 2'),
#             ('63', 'Ccr Diver 1'),
#             ('64', 'Ccr Diver 2'),
#             ('66', 'Pscr Diver'),
#             ('78', 'Apprentice Project: Cave 2'),
#             ('79', 'Apprentice Project: Tech 2'),
#             ('500', 'Gue-Dan Courses'),
#             ('69', 'Bls-D & Oxygen First Aid'),
#             ('70', 'Advanced Oxygen First Aid & Neuro'),
#             ('71', 'First Aid & Marine Life Injuries')],
#  'instructor': [('25411', 'Abell Yu Zhang'),
#                 ('26895', 'Ahmad Yaqoub Alhusaini'),
#                 ('69051', 'Ahmed Hagi'),
#                 ('17695', 'Alain Eid'),
#                 ('2073', 'Alberto Nava'),
#                 ('22617', 'Alessandro Vezzani'),
#                 ('1050', 'Andrea Marassich'),
#                 ('20546', 'Andrea Milani'),
#                 ('6578', 'Andrei Dmitriev'),
#                 ('22082', 'Andrew Couch'),
#                 ('2021', 'Anne-Marie Bresser'),
#                 ('9662', 'Annika Persson'),
#                 ('26064', 'Arthur Nguyen-Kim'),
#                 ('25915', 'Bartek Trzcinski'),
#                 ('22618', 'Belen Andres-Garcia'),
#                 ('11806', 'Benjamin Ott'),
#                 ('34', 'Bob Sherwood'),
#                 ('1011', 'Bruno Borelli'),
#                 ('10995', 'Bruno Espinosa'),
#                 ('21137', 'Cai Keke'),
#                 ('13375', 'Caterina De Seta'),
#                 ('26851', 'Charles Han'),
#                 ('3512', 'Chee Hoon Ong'),
#                 ('21066', 'Christian Höing'),
#                 ('25387', 'Christina Müller'),
#                 ('65203', 'Christof Müller'),
#                 ('304', 'Christophe Le Maillot'),
#                 ('15507', 'Claudia Haltern'),
#                 ('1999', 'Claudio Provenzani'),
#                 ('146', 'Daniel Riordan'),
#                 ('6754', 'Daniel Schulte'),
#                 ('19230', 'Dany Dulac'),
#                 ('7118', 'David Dusek'),
#                 ('105', 'David Rhea'),
#                 ('17681', 'David Sinwoo Lee'),
#                 ('4193', 'David Watson'),
#                 ('2366', 'Derk Remmers'),
#                 ('9369', 'Dimitris Fifis'),
#                 ('9665', 'Diogo Paulo'),
#                 ('2276', 'Dorota Czerny'),
#                 ('703', 'Douglas Mudry'),
#                 ('18320', 'Duncan Paterson'),
#                 ('3297', 'Edward Hayes'),
#                 ('20747', 'Emőke Wagner'),
#                 ('25873', 'Erik Wurz'),
#                 ('10169', 'Errol Kalayci'),
#                 ('64918', 'Esther Trösch'),
#                 ('21572', 'Fabio Portella'),
#                 ('14087', 'Ferry Schram'),
#                 ('22866', 'Francesco Cameli'),
#                 ('1026', 'Fred Devos'),
#                 ('11724', 'Gemma Thomas'),
#                 ('5878', 'German Arango'),
#                 ('428', 'Gideon Liew'),
#                 ('895', 'Graham Blackmore'),
#                 ('71766', 'Gue Hq'),
#                 ('5523', 'Guillermo Riesco'),
#                 ('2186', 'Gunnar Midtgaard'),
#                 ('4964', 'Guy Shockey'),
#                 ('4952', 'Hans Drexler'),
#                 ('13808', 'Heison Chak'),
#                 ('10673', 'Henning May'),
#                 ('23052', 'Huang Weiqi'),
#                 ('10441', 'Hui Jin'),
#                 ('19268', 'Imad Farhat'),
#                 ('13377', 'Irene Homberger'),
#                 ('10571', 'Ivan Wagner'),
#                 ('21332', 'Ivo Chiarino'),
#                 ('14279', 'Jaehun Sim'),
#                 ('26718', 'James Fraser'),
#                 ('25292', 'Jan Schmid'),
#                 ('10793', 'Jarkko Helin'),
#                 ('24473', 'Jason Cook'),
#                 ('16273', 'Jeroen Wilms'),
#                 ('25255', 'Jérôme Descamps'),
#                 ('25305', 'Jesper Haav'),
#                 ('4437', 'Jesper Kjøller'),
#                 ('15307', 'Jimmy Choo'),
#                 ('22468', 'Jin Ho Kim'),
#                 ('23227', 'Jinsong Ye'),
#                 ('25049', 'Jiwoo Lee'),
#                 ('1956', 'John Kendall'),
#                 ('13618', 'Jon Kieren'),
#                 ('68757', 'Jordan Allured'),
#                 ('21902', 'Joseph Robinson'),
#                 ('2458', 'Jp Bresser'),
#                 ('20167', 'Julio Cesar Cepeda Vargas'),
#                 ('18253', 'Jun Zhang'),
#                 ('24892', 'Jung-Han Hsieh'),
#                 ('17236', 'Junki Baek'),
#                 ('1770', 'Karim Hamza'),
#                 ('12172', 'Kees Beemster Leverenz'),
#                 ('12073', 'Keith Kreitner'),
#                 ('11950', 'Kelly Colwell'),
#                 ('8306', 'Kelvin Davidson'),
#                 ('69261', 'Kieran Hussey'),
#                 ('26073', 'Kim Hyunmo'),
#                 ('1411', 'Kirill A. Egorov'),
#                 ('20360', 'Kiyong Jang'),
#                 ('9597', 'Kyle Harmon'),
#                 ('68526', 'Kyung Jin Kim'),
#                 ('14654', 'Kyungsoo Kim'),
#                 ('20596', 'Laszlo Cseh'),
#                 ('24308', 'Lauren M. Wilson'),
#                 ('25023', 'Laurent Dahan'),
#                 ('27014', 'Lee Young Jae'),
#                 ('72114', 'Lereyce Josephs'),
#                 ('2117', 'Liam Allen'),
#                 ('70879', 'Lu Chen'),
#                 ('65259', 'Mahmoud Esmat'),
#                 ('3012', 'Manuela Schoch'),
#                 ('11850', 'Marco Colman'),
#                 ('13875', 'Marcus Rose'),
#                 ('515', 'Mario Arena'),
#                 ('7497', 'Mark Devoldere'),
#                 ('1032', 'Mark Messersmith'),
#                 ('8532', 'Martijn Blommaert'),
#                 ('23048', 'Martin Lessard'),
#                 ('18760', 'Matthijs Holtkamp'),
#                 ('25698', 'Mattia Popesso'),
#                 ('22659', 'Mauro Bordignon'),
#                 ('24581', 'Max Philip Frenkel'),
#                 ('66486', 'Maximilian Fahr'),
#                 ('2449', 'Meredith Tanguay'),
#                 ('65278', 'Michael Leung'),
#                 ('11259', 'Michael Pinault'),
#                 ('8228', 'Miko Zulueta'),
#                 ('17486', 'Myoung Hoon Kim'),
#                 ('15389', 'Neil Powell'),
#                 ('20397', 'Nevcan Uludaş'),
#                 ('6627', 'Niccolo Crespi'),
#                 ('1991', 'Nikos Vardakas'),
#                 ('26489', 'Norbert Lee'),
#                 ('14315', 'Nuno Padrao'),
#                 ('65111', 'Olga Martinelli'),
#                 ('68750', 'Oliver Ober'),
#                 ('15479', 'Oliver Reimer'),
#                 ('21901', 'Orie J. Braun'),
#                 ('1344', 'Osama Gobara'),
#                 ('15580', 'Paul Berkhout'),
#                 ('19962', 'Per Normark'),
#                 ('1374', 'Peter Gaertner'),
#                 ('20519', 'Ralf Duckheim'),
#                 ('20656', 'Raul Alvarez Garcia'),
#                 ('13234', 'Rhys Toone'),
#                 ('1591', 'Ricardo Constantino'),
#                 ('21570', 'Richard Spikings'),
#                 ('11026', 'Richard Van De Logt'),
#                 ('755', 'Richard Walker'),
#                 ('21650', 'Rick Van Beerendonk'),
#                 ('9201', 'Roger Hovind'),
#                 ('2428', 'Romano Rampazzo'),
#                 ('24907', 'Ron Fancher'),
#                 ('7785', 'Ryan Booker'),
#                 ('18431', 'Sameh Sokar'),
#                 ('12706', 'Sander Evering'),
#                 ('25628', 'Sangwon Lee'),
#                 ('20802', 'Sebastian Von Koss'),
#                 ('13626', 'Serena Keeler'),
#                 ('3666', 'Sergey Porkhachev'),
#                 ('20842', 'Sergio R Schirato'),
#                 ('5680', 'Stefano Di Cosimo'),
#                 ('14487', 'Stefano Gualtieri'),
#                 ('2474', 'Steve Blanchard'),
#                 ('4255', 'Steven Millington'),
#                 ('14655', 'Su Eun Kim'),
#                 ('7698', 'Sven Nelles'),
#                 ('2359', 'Thomas Jonsson'),
#                 ('17242', 'Tom Figueroa'),
#                 ('7005', 'William Wooill Hong'),
#                 ('13884', 'Xavier Vrijdag'),
#                 ('23171', 'Xiaodong Zhong'),
#                 ('20926', 'Xuan Chen'),
#                 ('23172', 'Yanbin Wu'),
#                 ('16137', 'Youngwoo Seo'),
#                 ('20059', 'Yousuke Ogiwara'),
#                 ('1444', 'Zsolt Szilagyi')],
#  'location': [('AO', 'Angola'),
#               ('EG', 'Egypt'),
#               ('MU', 'Mauritius'),
#               ('ZA', 'South Africa'),
#               ('AR', 'Argentina'),
#               ('BR', 'Brazil'),
#               ('CA', 'Canada'),
#               ('CL', 'Chile'),
#               ('CO', 'Colombia'),
#               ('HN', 'Honduras'),
#               ('MQ', 'Martinique'),
#               ('MX', 'Mexico'),
#               ('AN', 'Netherlands Antilles'),
#               ('US', 'United States'),
#               ('CN', 'China'),
#               ('HK', 'Hong Kong'),
#               ('IN', 'India'),
#               ('ID', 'Indonesia'),
#               ('JP', 'Japan'),
#               ('KR', 'Korea (South)'),
#               ('KW', 'Kuwait'),
#               ('LB', 'Lebanon'),
#               ('MY', 'Malaysia'),
#               ('OM', 'Oman'),
#               ('PH', 'Philippines'),
#               ('SA', 'Saudi Arabia'),
#               ('SG', 'Singapore'),
#               ('TW', 'Taiwan'),
#               ('TH', 'Thailand'),
#               ('TR', 'Turkey'),
#               ('AE', 'United Arab Emirates'),
#               ('AT', 'Austria'),
#               ('BE', 'Belgium'),
#               ('HR', 'Croatia'),
#               ('CY', 'Cyprus'),
#               ('CZ', 'Czech Republic'),
#               ('DK', 'Denmark'),
#               ('FI', 'Finland'),
#               ('FR', 'France'),
#               ('DE', 'Germany'),
#               ('GR', 'Greece'),
#               ('HU', 'Hungary'),
#               ('IT', 'Italy'),
#               ('MT', 'Malta'),
#               ('NL', 'Netherlands'),
#               ('NO', 'Norway'),
#               ('PL', 'Poland'),
#               ('PT', 'Portugal'),
#               ('RU', 'Russia'),
#               ('ES', 'Spain'),
#               ('SE', 'Sweden'),
#               ('CH', 'Switzerland'),
#               ('UA', 'Ukraine'),
#               ('UK', 'United Kingdom'),
#               ('AU', 'Australia'),
#               ('NZ', 'New Zealand'),
#               ('PG', 'Papua New Guinea')]}

# %%
# Retrieve Instructors by Countries 
countries = filter_results.get("location")
country_instructor_dict = {}

for country in countries:
    code, country_name = country
    instructors = []
    
    page = requests.get(GUE_INSTRUCTORS_URL + "?country=" + code).content
    soup = bs(page, 'html.parser')
    instructor_container = soup.find(name='div', attrs={"id": "Content"})
    for bold_element in instructor_container.find_all('b'):
        _link = bold_element.find("a")
        if _link and _link.get("href").startswith("/diver-training/"):
            instructors.append(_link.text.strip("\xa0\xa0").title())
    country_instructor_dict.update({code: instructors})
pprint(country_instructor_dict)
# Out:
# {'AE': ['Dimitris Fifis', 'Dorota Czerny', 'Jesper Kjøller', 'Mark Devoldere'],
#  'AN': ['German Arango'],
#  'AO': [],
#  'AR': ['Belen Andres-Garcia', 'Guillermo Riesco', 'Raul Alvarez Garcia'],
#  'AT': ['Christina Müller',
#         'Oliver Reimer',
#         'Osama Gobara',
#         'Sebastian Von Koss'],
#  'AU': ['Duncan Paterson',
#         'Kieran Hussey',
#         'Liam Allen',
#         'Rhys Toone',
#         'Ryan Booker'],
#  'BE': ['Jérôme Descamps',
#         'Mark Devoldere',
#         'Martijn Blommaert',
#         'Richard Van De Logt',
#         'Sander Evering'],
#  'BR': ['Ricardo Constantino', 'Sergio R Schirato'],
#  'CA': ['Alain Eid',
#         'Dany Dulac',
#         'Guy Shockey',
#         'Heison Chak',
#         'Imad Farhat',
#         'Jason Cook',
#         'Martin Lessard',
#         'Michael Pinault',
#         'Steve Blanchard'],
#  'CH': ['Caterina De Seta',
#         'Irene Homberger',
#         'Ivan Wagner',
#         'Maximilian Fahr',
#         'Oliver Ober',
#         'Richard Spikings',
#         'Romano Rampazzo'],
#  'CL': ['Guillermo Riesco'],
#  'CN': ['Abell Yu Zhang',
#         'Cai Keke',
#         'Huang Weiqi',
#         'Hui Jin',
#         'Jinsong Ye',
#         'Jun Zhang',
#         'Lu Chen',
#         'William Wooill Hong',
#         'Xiaodong Zhong',
#         'Xuan Chen',
#         'Yanbin Wu'],
#  'CO': ['German Arango', 'Julio Cesar Cepeda Vargas'],
#  'CY': ['Imad Farhat', 'Nikos Vardakas'],
#  'CZ': ['David Dusek'],
#  'DE': ['Benjamin Ott',
#         'Christian Höing',
#         'Christina Müller',
#         'Christof Müller',
#         'Claudia Haltern',
#         'Daniel Schulte',
#         'Derk Remmers',
#         'Esther Trösch',
#         'Hans Drexler',
#         'Henning May',
#         'Jan Schmid',
#         'Jp Bresser',
#         'Keith Kreitner',
#         'Manuela Schoch',
#         'Matthijs Holtkamp',
#         'Maximilian Fahr',
#         'Oliver Ober',
#         'Oliver Reimer',
#         'Peter Gaertner',
#         'Ralf Duckheim',
#         'Sebastian Von Koss',
#         'Sven Nelles'],
#  'DK': ['Jesper Kjøller'],
#  'EG': ['Ahmed Hagi',
#         'Andrei Dmitriev',
#         'Mahmoud Esmat',
#         'Niccolo Crespi',
#         'Sameh Sokar'],
#  'ES': ['Belen Andres-Garcia',
#         'Julio Cesar Cepeda Vargas',
#         'Lu Chen',
#         'Nuno Padrao',
#         'Raul Alvarez Garcia',
#         'Ricardo Constantino'],
#  'FI': ['Jarkko Helin'],
#  'FR': ['Andrea Marassich',
#         'Arthur Nguyen-Kim',
#         'Irene Homberger',
#         'Jérôme Descamps'],
#  'GR': ['Derk Remmers', 'Dimitris Fifis', 'Nikos Vardakas'],
#  'HK': ['Andrew Couch', 'Graham Blackmore', 'Heison Chak', 'Hui Jin'],
#  'HN': ['Laurent Dahan'],
#  'HR': ['Daniel Schulte',
#         'Henning May',
#         'Jeroen Wilms',
#         'Mario Arena',
#         'Mattia Popesso',
#         'Richard Walker',
#         'Stefano Gualtieri',
#         'Sven Nelles',
#         'Zsolt Szilagyi'],
#  'HU': ['Emőke Wagner', 'Laszlo Cseh', 'Zsolt Szilagyi'],
#  'ID': ['Jimmy Choo', 'Michael Leung'],
#  'IN': [],
#  'IT': ['Ahmed Hagi',
#         'Alessandro Vezzani',
#         'Andrea Marassich',
#         'Andrea Milani',
#         'Bruno Borelli',
#         'Caterina De Seta',
#         'Claudio Provenzani',
#         'Fabio Portella',
#         'Francesco Cameli',
#         'Ivan Wagner',
#         'Jordan Allured',
#         'Marco Colman',
#         'Mario Arena',
#         'Mattia Popesso',
#         'Mauro Bordignon',
#         'Niccolo Crespi',
#         'Olga Martinelli',
#         'Peter Gaertner',
#         'Romano Rampazzo',
#         'Stefano Di Cosimo',
#         'Stefano Gualtieri'],
#  'JP': ['Thomas Jonsson', 'Yousuke Ogiwara'],
#  'KR': ['David Sinwoo Lee',
#         'Jaehun Sim',
#         'Jin Ho Kim',
#         'Jiwoo Lee',
#         'Junki Baek',
#         'Kim Hyunmo',
#         'Kiyong Jang',
#         'Kyung Jin Kim',
#         'Kyungsoo Kim',
#         'Lee Young Jae',
#         'Myoung Hoon Kim',
#         'Sangwon Lee',
#         'Su Eun Kim',
#         'William Wooill Hong',
#         'Youngwoo Seo'],
#  'KW': ['Ahmad Yaqoub Alhusaini'],
#  'LB': [],
#  'MQ': [],
#  'MT': ['John Kendall', 'Keith Kreitner'],
#  'MU': [],
#  'MX': ['Alberto Nava',
#         'Alessandro Vezzani',
#         'Annika Persson',
#         'Arthur Nguyen-Kim',
#         'Bruno Espinosa',
#         'Christophe Le Maillot',
#         'Daniel Riordan',
#         'David Dusek',
#         'David Watson',
#         'Emőke Wagner',
#         'Fred Devos',
#         'Ivo Chiarino',
#         'Jan Schmid',
#         'Jon Kieren',
#         'Kelvin Davidson',
#         'Laszlo Cseh',
#         'Laurent Dahan',
#         'Mauro Bordignon',
#         'Osama Gobara'],
#  'MY': ['Gemma Thomas'],
#  'NL': ['Anne-Marie Bresser',
#         'Benjamin Ott',
#         'Erik Wurz',
#         'Ferry Schram',
#         'Jeroen Wilms',
#         'Jp Bresser',
#         'Martijn Blommaert',
#         'Matthijs Holtkamp',
#         'Paul Berkhout',
#         'Richard Van De Logt',
#         'Rick Van Beerendonk',
#         'Sander Evering',
#         'Xavier Vrijdag'],
#  'NO': ['Annika Persson', 'Gunnar Midtgaard'],
#  'NZ': ['Serena Keeler', 'Xavier Vrijdag'],
#  'OM': ['Nevcan Uludaş'],
#  'PG': [],
#  'PH': ['Abell Yu Zhang',
#         'Andrew Couch',
#         'Cai Keke',
#         'David Sinwoo Lee',
#         'Huang Weiqi',
#         'Jaehun Sim',
#         'Jin Ho Kim',
#         'Jinsong Ye',
#         'Junki Baek',
#         'Kim Hyunmo',
#         'Kiyong Jang',
#         'Kyung Jin Kim',
#         'Kyungsoo Kim',
#         'Lee Young Jae',
#         'Miko Zulueta',
#         'Sangwon Lee',
#         'Su Eun Kim',
#         'Yanbin Wu',
#         'Youngwoo Seo'],
#  'PL': ['Bartek Trzcinski', 'Dorota Czerny'],
#  'PT': ['Diogo Paulo', 'Nuno Padrao'],
#  'RU': ['Andrei Dmitriev', 'Kirill A. Egorov', 'Sergey Porkhachev'],
#  'SA': ['Ahmad Yaqoub Alhusaini'],
#  'SE': ['Anne-Marie Bresser',
#         'Gunnar Midtgaard',
#         'Jesper Haav',
#         'Per Normark',
#         'Roger Hovind'],
#  'SG': ['Chee Hoon Ong',
#         'Gemma Thomas',
#         'Gideon Liew',
#         'Jimmy Choo',
#         'Michael Leung'],
#  'TH': [],
#  'TR': ['Nevcan Uludaş'],
#  'TW': [],
#  'UA': ['Per Normark'],
#  'UK': ['Graham Blackmore',
#         'John Kendall',
#         'Jordan Allured',
#         'Joseph Robinson',
#         'Marcus Rose',
#         'Neil Powell',
#         'Richard Walker'],
#  'US': ['Alberto Nava',
#         'Bob Sherwood',
#         'Charles Han',
#         'Daniel Riordan',
#         'David Rhea',
#         'David Watson',
#         'Douglas Mudry',
#         'Edward Hayes',
#         'Errol Kalayci',
#         'Francesco Cameli',
#         'Guy Shockey',
#         'James Fraser',
#         'Jon Kieren',
#         'Jung-Han Hsieh',
#         'Karim Hamza',
#         'Kees Beemster Leverenz',
#         'Kelly Colwell',
#         'Kirill A. Egorov',
#         'Kyle Harmon',
#         'Lauren M. Wilson',
#         'Mark Messersmith',
#         'Max Philip Frenkel',
#         'Meredith Tanguay',
#         'Norbert Lee',
#         'Orie J. Braun',
#         'Ron Fancher',
#         'Sergio R Schirato',
#         'Steven Millington',
#         'Tom Figueroa'],
#  'ZA': ['Sameh Sokar']}

# %% [markdown]
# ## Build Datasets

# %%
instructor_names = [x[1] for x in filter_results.get("instructor")]
instructor_names
# Out:
# ['Abell Yu Zhang',
#  'Ahmad Yaqoub Alhusaini',
#  'Ahmed Hagi',
#  'Alain Eid',
#  'Alberto Nava',
#  'Alessandro Vezzani',
#  'Andrea Marassich',
#  'Andrea Milani',
#  'Andrei Dmitriev',
#  'Andrew Couch',
#  'Anne-Marie Bresser',
#  'Annika Persson',
#  'Arthur Nguyen-Kim',
#  'Bartek Trzcinski',
#  'Belen Andres-Garcia',
#  'Benjamin Ott',
#  'Bob Sherwood',
#  'Bruno Borelli',
#  'Bruno Espinosa',
#  'Cai Keke',
#  'Caterina De Seta',
#  'Charles Han',
#  'Chee Hoon Ong',
#  'Christian Höing',
#  'Christina Müller',
#  'Christof Müller',
#  'Christophe Le Maillot',
#  'Claudia Haltern',
#  'Claudio Provenzani',
#  'Daniel Riordan',
#  'Daniel Schulte',
#  'Dany Dulac',
#  'David Dusek',
#  'David Rhea',
#  'David Sinwoo Lee',
#  'David Watson',
#  'Derk Remmers',
#  'Dimitris Fifis',
#  'Diogo Paulo',
#  'Dorota Czerny',
#  'Douglas Mudry',
#  'Duncan Paterson',
#  'Edward Hayes',
#  'Emőke Wagner',
#  'Erik Wurz',
#  'Errol Kalayci',
#  'Esther Trösch',
#  'Fabio Portella',
#  'Ferry Schram',
#  'Francesco Cameli',
#  'Fred Devos',
#  'Gemma Thomas',
#  'German Arango',
#  'Gideon Liew',
#  'Graham Blackmore',
#  'Gue Hq',
#  'Guillermo Riesco',
#  'Gunnar Midtgaard',
#  'Guy Shockey',
#  'Hans Drexler',
#  'Heison Chak',
#  'Henning May',
#  'Huang Weiqi',
#  'Hui Jin',
#  'Imad Farhat',
#  'Irene Homberger',
#  'Ivan Wagner',
#  'Ivo Chiarino',
#  'Jaehun Sim',
#  'James Fraser',
#  'Jan Schmid',
#  'Jarkko Helin',
#  'Jason Cook',
#  'Jeroen Wilms',
#  'Jérôme Descamps',
#  'Jesper Haav',
#  'Jesper Kjøller',
#  'Jimmy Choo',
#  'Jin Ho Kim',
#  'Jinsong Ye',
#  'Jiwoo Lee',
#  'John Kendall',
#  'Jon Kieren',
#  'Jordan Allured',
#  'Joseph Robinson',
#  'Jp Bresser',
#  'Julio Cesar Cepeda Vargas',
#  'Jun Zhang',
#  'Jung-Han Hsieh',
#  'Junki Baek',
#  'Karim Hamza',
#  'Kees Beemster Leverenz',
#  'Keith Kreitner',
#  'Kelly Colwell',
#  'Kelvin Davidson',
#  'Kieran Hussey',
#  'Kim Hyunmo',
#  'Kirill A. Egorov',
#  'Kiyong Jang',
#  'Kyle Harmon',
#  'Kyung Jin Kim',
#  'Kyungsoo Kim',
#  'Laszlo Cseh',
#  'Lauren M. Wilson',
#  'Laurent Dahan',
#  'Lee Young Jae',
#  'Lereyce Josephs',
#  'Liam Allen',
#  'Lu Chen',
#  'Mahmoud Esmat',
#  'Manuela Schoch',
#  'Marco Colman',
#  'Marcus Rose',
#  'Mario Arena',
#  'Mark Devoldere',
#  'Mark Messersmith',
#  'Martijn Blommaert',
#  'Martin Lessard',
#  'Matthijs Holtkamp',
#  'Mattia Popesso',
#  'Mauro Bordignon',
#  'Max Philip Frenkel',
#  'Maximilian Fahr',
#  'Meredith Tanguay',
#  'Michael Leung',
#  'Michael Pinault',
#  'Miko Zulueta',
#  'Myoung Hoon Kim',
#  'Neil Powell',
#  'Nevcan Uludaş',
#  'Niccolo Crespi',
#  'Nikos Vardakas',
#  'Norbert Lee',
#  'Nuno Padrao',
#  'Olga Martinelli',
#  'Oliver Ober',
#  'Oliver Reimer',
#  'Orie J. Braun',
#  'Osama Gobara',
#  'Paul Berkhout',
#  'Per Normark',
#  'Peter Gaertner',
#  'Ralf Duckheim',
#  'Raul Alvarez Garcia',
#  'Rhys Toone',
#  'Ricardo Constantino',
#  'Richard Spikings',
#  'Richard Van De Logt',
#  'Richard Walker',
#  'Rick Van Beerendonk',
#  'Roger Hovind',
#  'Romano Rampazzo',
#  'Ron Fancher',
#  'Ryan Booker',
#  'Sameh Sokar',
#  'Sander Evering',
#  'Sangwon Lee',
#  'Sebastian Von Koss',
#  'Serena Keeler',
#  'Sergey Porkhachev',
#  'Sergio R Schirato',
#  'Stefano Di Cosimo',
#  'Stefano Gualtieri',
#  'Steve Blanchard',
#  'Steven Millington',
#  'Su Eun Kim',
#  'Sven Nelles',
#  'Thomas Jonsson',
#  'Tom Figueroa',
#  'William Wooill Hong',
#  'Xavier Vrijdag',
#  'Xiaodong Zhong',
#  'Xuan Chen',
#  'Yanbin Wu',
#  'Youngwoo Seo',
#  'Yousuke Ogiwara',
#  'Zsolt Szilagyi']

# %%
df_instructors = pd.DataFrame(instructor_names, columns=['instructor'])
df_instructors
# Out:
#                  instructor
# 0            Abell Yu Zhang
# 1    Ahmad Yaqoub Alhusaini
# 2                Ahmed Hagi
# 3                 Alain Eid
# 4              Alberto Nava
# ..                      ...
# 172               Xuan Chen
# 173               Yanbin Wu
# 174            Youngwoo Seo
# 175         Yousuke Ogiwara
# 176          Zsolt Szilagyi
#
# [177 rows x 1 columns]

# %%
rev_country_instructor_dict = {}

rev_country_instructor_dict = {}
for key, value in country_instructor_dict.items():
    for name in value:
        if name not in rev_country_instructor_dict.keys():
            rev_country_instructor_dict.update({name: f"{key}, "})
        else:
            _value = rev_country_instructor_dict.get(name)
            _value += key + ", "
            rev_country_instructor_dict.update({name: _value})

df_instructor_countries = pd.DataFrame(rev_country_instructor_dict.items(), columns=['instructor', 'countries'])
df_instructor_countries['countries'] = df_instructor_countries['countries'].str.rstrip(', ')
df_instructor_countries.sample(3)
# Out:
#              instructor countries
# 41          Charles Han        US
# 23   Alessandro Vezzani    MX, IT
# 151  Anne-Marie Bresser    NL, SE

# %%
set(df_instructors['instructor']) - set(df_instructor_countries['instructor'])
# Out:
# {'Gue Hq', 'Lereyce Josephs'}

# %% [markdown]
# Upon further checking, `Gue Hq` and `Lereyce Josephs` both do not have resume on GUE.com as of 6 Nov 2023.

# %%
# Map Country codes to Country Names
country_code_enum = dict(filter_results.get('location'))
df_instructor_countries['countries'] = df_instructor_countries['countries'].apply(lambda x:", ".join([country_code_enum.get(y) for y in x.split(", ")]))
df_instructor_countries.sample(3)
# Out:
#         instructor                   countries
# 93    Youngwoo Seo  Korea (South), Philippines
# 40    Bob Sherwood               United States
# 105  Oliver Reimer            Austria, Germany

# %%
df_instructor_countries.to_csv('../data/instructors_countries.csv', index=False)
